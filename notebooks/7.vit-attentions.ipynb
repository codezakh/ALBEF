# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
import IPython.display

# %%
sys.path.insert(0, "/home/mai/zkhan/ALBEF")

# %%
import matplotlib.pyplot as plt
import skimage.io
from matplotlib.patches import Polygon
import cv2
import random
import colorsys
import os
from torch import nn
from skimage.measure import find_contours

# %%
def apply_mask(image, mask, color, alpha=0.5):
    for c in range(3):
        image[:, :, c] = image[:, :, c] * (1 - alpha * mask) + alpha * mask * color[c] * 255
    return image

# %%
def random_colors(N, bright=True):
    """
    Generate random colors.
    """
    brightness = 1.0 if bright else 0.7
    hsv = [(i / N, 1, brightness) for i in range(N)]
    colors = list(map(lambda c: colorsys.hsv_to_rgb(*c), hsv))
    random.shuffle(colors)
    return colors

# %%
def display_instances(image, mask, fname="test", figsize=(5, 5), blur=False, contour=True, alpha=0.5):
    fig = plt.figure(figsize=figsize, frameon=False)
    ax = plt.Axes(fig, [0., 0., 1., 1.])
    ax.set_axis_off()
    fig.add_axes(ax)
    ax = plt.gca()

    N = 1
    mask = mask[None, :, :]
    # Generate random colors
    colors = random_colors(N)

    # Show area outside image boundaries.
    height, width = image.shape[:2]
    margin = 0
    ax.set_ylim(height + margin, -margin)
    ax.set_xlim(-margin, width + margin)
    ax.axis('off')
    masked_image = image.astype(np.uint32).copy()
    for i in range(N):
        color = colors[i]
        _mask = mask[i]
        if blur:
            _mask = cv2.blur(_mask,(10,10))
        # Mask
        masked_image = apply_mask(masked_image, _mask, color, alpha)
        # Mask Polygon
        # Pad to ensure proper polygons for masks that touch image edges.
        if contour:
            padded_mask = np.zeros((_mask.shape[0] + 2, _mask.shape[1] + 2))
            padded_mask[1:-1, 1:-1] = _mask
            contours = find_contours(padded_mask, 0.5)
            for verts in contours:
                # Subtract the padding and flip (y, x) to (x, y)
                verts = np.fliplr(verts) - 1
                p = Polygon(verts, facecolor="none", edgecolor=color)
                ax.add_patch(p)
    ax.imshow(masked_image.astype(np.uint8), aspect='auto')
    fig.savefig(fname)
    print(f"{fname} saved.")
    return

# %%
import torch
from torchvision import transforms
from torchvision.transforms.functional import to_pil_image, to_tensor, resize
from PIL import Image, ImageDraw, ImageFont
import torch.nn.functional as F
import torchvision
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
from models.tokenization_bert import BertTokenizer
from models.singlestream_v2.baseline_retrieval import ALBEF

# %%
import json
import random
import ruamel.yaml as yaml
from wordcloud import WordCloud
from nltk.corpus import wordnet as wn
import spacy

# %%
nlp = spacy.load('en_core_web_sm')

# %%
from dataset.utils import pre_caption

# %%
with open('/net/acadia10a/data/zkhan/cc12m-json/100k.json', 'r') as f:
    cc100k = json.load(f)

# %%
normalize = transforms.Normalize((0.48145466, 0.4578275, 0.40821073), (0.26862954, 0.26130258, 0.27577711))
test_transform = transforms.Compose([
        transforms.Resize((256,256),interpolation=Image.BICUBIC),
        transforms.ToTensor(),
        normalize,
])

view_transform = transforms.Compose([
        transforms.Resize((256,256),interpolation=Image.BICUBIC),
        transforms.ToTensor(),
])



with open('../configs/ablations/Pretrain4M_SharedTxtEncoder.yaml', 'r') as f:
    config = yaml.load(f, Loader=yaml.Loader)
# patch the BERT config to be an absolute path because we're running
# the code from a different directory
config['bert_config'] = '/home/mai/zkhan/ALBEF/configs/shared_bert.json'

tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = ALBEF(config=config, text_encoder='bert-base-uncased', tokenizer=tokenizer, init_deit=True)
checkpoint = torch.load(
    '/net/acadia10a/data/zkhan/ALBEF-checkpoints/ablations/shared_txt_enc_pseudolabels_multimodal_mim_momentum/checkpoint_29.pth',
    map_location='cpu'
)
state_dict = checkpoint['model']
for key in list(state_dict.keys()):
    if 'bert' in key:
        encoder_key = key.replace('bert.','')         
        state_dict[encoder_key] = state_dict[key] 
        del state_dict[key]                
msg = model.load_state_dict(state_dict,strict=False) 

device = torch.device('cuda')
model.eval();
model = model.to(device)
# Out:
# /home/mai/zkhan/miniconda3/envs/ssl/lib/python3.7/site-packages/torchvision/transforms/transforms.py:281: UserWarning: Argument interpolation should be of type InterpolationMode instead of int. Please, use InterpolationMode enum.
#   "Argument interpolation should be of type InterpolationMode instead of int. "
# reshape position embedding from 196 to 256
# _IncompatibleKeys(missing_keys=['mask_token'], unexpected_keys=['head.weight', 'head.bias'])
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['bert.embeddings.token_type_embeddings.weight', 'cls.seq_relationship.bias', 'cls.predictions.bias', 'bert.pooler.dense.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight', 'bert.pooler.dense.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertModel were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['bert.encoder.layer.11.crossattention.self.value.bias', 'bert.encoder.layer.11.crossattention.output.dense.bias', 'bert.encoder.layer.0.crossattention.self.query.bias', 'bert.encoder.layer.6.crossattention.output.dense.bias', 'bert.encoder.layer.4.crossattention.output.dense.bias', 'bert.encoder.layer.9.crossattention.self.value.weight', 'bert.encoder.layer.9.crossattention.output.dense.bias', 'bert.encoder.layer.9.crossattention.self.value.bias', 'bert.encoder.layer.5.crossattention.self.query.bias', 'bert.encoder.layer.0.crossattention.self.value.weight', 'bert.encoder.layer.4.crossattention.self.value.weight', 'bert.encoder.layer.10.crossattention.output.dense.bias', 'bert.encoder.layer.9.crossattention.self.key.weight', 'bert.encoder.layer.7.crossattention.output.dense.weight', 'bert.encoder.layer.6.crossattention.self.query.weight', 'bert.encoder.layer.6.crossattention.output.LayerNorm.bias', 'bert.encoder.layer.4.crossattention.self.key.bias', 'bert.encoder.layer.0.crossattention.self.query.weight', 'bert.encoder.layer.11.crossattention.self.query.weight', 'bert.encoder.layer.0.crossattention.output.LayerNorm.bias', 'bert.encoder.layer.3.crossattention.self.key.weight', 'bert.encoder.layer.4.crossattention.output.LayerNorm.weight', 'bert.encoder.layer.2.crossattention.output.dense.weight', 'bert.encoder.layer.6.crossattention.self.key.weight', 'bert.encoder.layer.6.crossattention.self.value.bias', 'bert.encoder.layer.1.crossattention.self.key.bias', 'bert.encoder.layer.1.crossattention.output.LayerNorm.bias', 'bert.encoder.layer.2.crossattention.self.key.bias', 'bert.encoder.layer.11.crossattention.output.dense.weight', 'bert.encoder.layer.2.crossattention.output.LayerNorm.weight', 'bert.encoder.layer.5.crossattention.self.query.weight', 'bert.encoder.layer.11.crossattention.output.LayerNorm.weight', 'bert.encoder.layer.1.crossattention.self.value.bias', 'bert.encoder.layer.2.crossattention.output.LayerNorm.bias', 'bert.encoder.layer.9.crossattention.output.LayerNorm.bias', 'bert.encoder.layer.2.crossattention.self.query.weight', 'bert.encoder.layer.9.crossattention.output.LayerNorm.weight', 'bert.encoder.layer.10.crossattention.self.value.weight', 'bert.encoder.layer.7.crossattention.self.query.bias', 'bert.encoder.layer.7.crossattention.self.value.weight', 'bert.encoder.layer.10.crossattention.self.key.bias', 'bert.encoder.layer.1.crossattention.output.dense.bias', 'bert.encoder.layer.3.crossattention.output.dense.bias', 'bert.encoder.layer.6.crossattention.output.dense.weight', 'bert.encoder.layer.8.crossattention.output.dense.weight', 'bert.encoder.layer.8.crossattention.output.dense.bias', 'bert.encoder.layer.4.crossattention.self.value.bias', 'bert.encoder.layer.2.crossattention.self.value.bias', 'bert.encoder.layer.9.crossattention.self.query.weight', 'bert.encoder.layer.10.crossattention.output.LayerNorm.weight', 'bert.encoder.layer.3.crossattention.self.value.weight', 'bert.encoder.layer.10.crossattention.self.query.bias', 'bert.encoder.layer.7.crossattention.self.key.weight', 'bert.encoder.layer.10.crossattention.output.dense.weight', 'bert.encoder.layer.2.crossattention.self.query.bias', 'bert.encoder.layer.8.crossattention.self.query.bias', 'bert.encoder.layer.8.crossattention.output.LayerNorm.weight', 'bert.encoder.layer.0.crossattention.self.key.weight', 'bert.encoder.layer.2.crossattention.self.key.weight', 'bert.encoder.layer.7.crossattention.output.LayerNorm.bias', 'bert.encoder.layer.11.crossattention.self.key.weight', 'bert.encoder.layer.8.crossattention.self.value.bias', 'bert.encoder.layer.10.crossattention.self.query.weight', 'bert.encoder.layer.7.crossattention.output.dense.bias', 'bert.encoder.layer.3.crossattention.output.LayerNorm.weight', 'bert.encoder.layer.3.crossattention.self.query.bias', 'bert.encoder.layer.9.crossattention.output.dense.weight', 'bert.encoder.layer.11.c ...
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['bert.embeddings.token_type_embeddings.weight', 'cls.seq_relationship.bias', 'cls.predictions.bias', 'bert.pooler.dense.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight', 'bert.pooler.dense.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertModel were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['bert.encoder.layer.11.crossattention.self.value.bias', 'bert.encoder.layer.11.crossattention.output.dense.bias', 'bert.encoder.layer.0.crossattention.self.query.bias', 'bert.encoder.layer.6.crossattention.output.dense.bias', 'bert.encoder.layer.4.crossattention.output.dense.bias', 'bert.encoder.layer.9.crossattention.self.value.weight', 'bert.encoder.layer.9.crossattention.output.dense.bias', 'bert.encoder.layer.9.crossattention.self.value.bias', 'bert.encoder.layer.5.crossattention.self.query.bias', 'bert.encoder.layer.0.crossattention.self.value.weight', 'bert.encoder.layer.4.crossattention.self.value.weight', 'bert.encoder.layer.10.crossattention.output.dense.bias', 'bert.encoder.layer.9.crossattention.self.key.weight', 'bert.encoder.layer.7.crossattention.output.dense.weight', 'bert.encoder.layer.6.crossattention.self.query.weight', 'bert.encoder.layer.6.crossattention.output.LayerNorm.bias', 'bert.encoder.layer.4.crossattention.self.key.bias', 'bert.encoder.layer.0.crossattention.self.query.weight', 'bert.encoder.layer.11.crossattention.self.query.weight', 'bert.encoder.layer.0.crossattention.output.LayerNorm.bias', 'bert.encoder.layer.3.crossattention.self.key.weight', 'bert.encoder.layer.4.crossattention.output.LayerNorm.weight', 'bert.encoder.layer.2.crossattention.output.dense.weight', 'bert.encoder.layer.6.crossattention.self.key.weight', 'bert.encoder.layer.6.crossattention.self.value.bias', 'bert.encoder.layer.1.crossattention.self.key.bias', 'bert.encoder.layer.1.crossattention.output.LayerNorm.bias', 'bert.encoder.layer.2.crossattention.self.key.bias', 'bert.encoder.layer.11.crossattention.output.dense.weight', 'bert.encoder.layer.2.crossattention.output.LayerNorm.weight', 'bert.encoder.layer.5.crossattention.self.query.weight', 'bert.encoder.layer.11.crossattention.output.LayerNorm.weight', 'bert.encoder.layer.1.crossattention.self.value.bias', 'bert.encoder.layer.2.crossattention.output.LayerNorm.bias', 'bert.encoder.layer.9.crossattention.output.LayerNorm.bias', 'bert.encoder.layer.2.crossattention.self.query.weight', 'bert.encoder.layer.9.crossattention.output.LayerNorm.weight', 'bert.encoder.layer.10.crossattention.self.value.weight', 'bert.encoder.layer.7.crossattention.self.query.bias', 'bert.encoder.layer.7.crossattention.self.value.weight', 'bert.encoder.layer.10.crossattention.self.key.bias', 'bert.encoder.layer.1.crossattention.output.dense.bias', 'bert.encoder.layer.3.crossattention.output.dense.bias', 'bert.encoder.layer.6.crossattention.output.dense.weight', 'bert.encoder.layer.8.crossattention.output.dense.weight', 'bert.encoder.layer.8.crossattention.output.dense.bias', 'bert.encoder.layer.4.crossattention.self.value.bias', 'bert.encoder.layer.2.crossattention.self.value.bias', 'bert.encoder.layer.9.crossattention.self.query.weight', 'bert.encoder.layer.10.crossattention.output.LayerNorm.weight', 'bert.encoder.layer.3.crossattention.self.value.weight', 'bert.encoder.layer.10.crossattention.self.query.bias', 'bert.encoder.layer.7.crossattention.self.key.weight', 'bert.encoder.layer.10.crossattention.output.dense.weight', 'bert.encoder.layer.2.crossattention.self.query.bias', 'bert.encoder.layer.8.crossattention.self.query.bias', 'bert.encoder.layer.8.crossattention.output.LayerNorm.weight', 'bert.encoder.layer.0.crossattention.self.key.weight', 'bert.encoder.layer.2.crossattention.self.key.weight', 'bert.encoder.layer.7.crossattention.output.LayerNorm.bias', 'bert.encoder.layer.11.crossattention.self.key.weight', 'bert.encoder.layer.8.crossattention.self.value.bias', 'bert.encoder.layer.10.crossattention.self.query.weight', 'bert.encoder.layer.7.crossattention.output.dense.bias', 'bert.encoder.layer.3.crossattention.output.LayerNorm.weight', 'bert.encoder.layer.3.crossattention.self.query.bias', 'bert.encoder.layer.9.crossattention.output.dense.weight', 'bert.encoder.layer.11.c ...
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
sample = random.choice(cc100k)
print(sample['caption'])
IPython.display.Image(sample['image'], width=300)
# Out:
# The building where the hotel is located

# %%
image = test_transform(Image.open(sample['image']).convert('RGB'))
view_image = view_transform(Image.open(sample['image']).convert('RGB'))

# %%
caption = pre_caption(sample['caption'], 30)
caption
# Out:
# 'the building where the hotel is located'

# %%
image = image.to(device)

# %%
text = tokenizer(caption, padding='longest', truncation=True, max_length=25, return_tensors="pt").to(device)

# %%
image_embeds = model.visual_encoder(image.unsqueeze(0), register_blk=11)
image_embeds.shape
# Out:
# torch.Size([1, 257, 768])

# %%
self_att_i = model.visual_encoder.blocks[11].attn.get_attention_map()
self_att_i.shape
# Out:
# torch.Size([1, 12, 257, 257])

# %%
nh = self_att_i.shape[1]
attentions = self_att_i[0, :, 0, 1:].reshape(nh, -1).cpu()

# %%
threshold = 0.8
val, idx = torch.sort(attentions)
val /= torch.sum(val, dim=1, keepdim=True)
cumval = torch.cumsum(val, dim=1)
th_attn = cumval > (1 - threshold)
idx2 = torch.argsort(idx)
for head in range(nh):
    th_attn[head] = th_attn[head][idx2[head]]
th_attn = th_attn.reshape(nh, 16, 16).float()
th_attn = nn.functional.interpolate(th_attn.unsqueeze(0), scale_factor=16, mode="nearest")[0].cpu().numpy()

# %%
patch_size = 16
attentions = attentions.detach().reshape(nh, 16, 16) # reshape it back into a grid based on the # of patches
attentions = F.interpolate(attentions.unsqueeze(0), scale_factor=patch_size, mode="nearest")[0].cpu().numpy()

# %%
img = view_image
output_dir = 'vis_outputs'
os.makedirs(output_dir, exist_ok=True)
torchvision.utils.save_image(torchvision.utils.make_grid(img, normalize=True, scale_each=True), os.path.join(output_dir, "img.png"))
for j in range(nh):
    fname = os.path.join(output_dir, "attn-head" + str(j) + ".png")
    plt.imsave(fname=fname, arr=attentions[j], format='png')
    print(f"{fname} saved.")
# Out:
# vis_outputs/attn-head0.png saved.
# vis_outputs/attn-head1.png saved.
# vis_outputs/attn-head2.png saved.
# vis_outputs/attn-head3.png saved.
# vis_outputs/attn-head4.png saved.
# vis_outputs/attn-head5.png saved.
# vis_outputs/attn-head6.png saved.
# vis_outputs/attn-head7.png saved.
# vis_outputs/attn-head8.png saved.
# vis_outputs/attn-head9.png saved.
# vis_outputs/attn-head10.png saved.
# vis_outputs/attn-head11.png saved.

# %%
image = skimage.io.imread(os.path.join(output_dir, "img.png"))
for j in range(nh):
    display_instances(image, th_attn[j], fname=os.path.join(output_dir, "mask_th" + str(threshold) + "_head" + str(j) +".png"), blur=False)
# Out:
# vis_outputs/mask_th0.8_head0.png saved.
# vis_outputs/mask_th0.8_head1.png saved.
# vis_outputs/mask_th0.8_head2.png saved.
# vis_outputs/mask_th0.8_head3.png saved.
# vis_outputs/mask_th0.8_head4.png saved.
# vis_outputs/mask_th0.8_head5.png saved.
# vis_outputs/mask_th0.8_head6.png saved.
# vis_outputs/mask_th0.8_head7.png saved.
# vis_outputs/mask_th0.8_head8.png saved.
# vis_outputs/mask_th0.8_head9.png saved.
# vis_outputs/mask_th0.8_head10.png saved.
# vis_outputs/mask_th0.8_head11.png saved.

# %%
image_atts = torch.ones(image_embeds.shape[:-1]).to(device)
image_atts.shape
# Out:
# torch.Size([1, 257])

# %%
with torch.no_grad():
    model_output = model.text_encoder(
        text.input_ids, 
        attention_mask=text.attention_mask,
        encoder_hidden_states=image_embeds,
        encoder_attention_mask=image_atts,
        return_dict=True, mode='multimodal',
        output_attentions=True
    )

# %%
len(model_output.attentions)
# Out:
# 12

# %%
model_output.attentions[0].shape
# Out:
# torch.Size([1, 12, 13, 13])

# %%
head = 5
level = 0
fig, (ax1, ax2, ax3) = plt.subplots(nrows=3, ncols=1, figsize=(20, 10), sharex=True, gridspec_kw={'height_ratios': (10, 1, 1)})
sns.heatmap(model_output.attentions[head].squeeze()[level].cpu().numpy(), ax=ax1, cbar=False, cmap='viridis_r')
#sns.heatmap(token_type_ids.cpu().numpy(), ax=ax2, cbar=False, cmap='rainbow')
#ax3.bar(np.arange(token_type_ids.shape[-1]), model_output.attentions[head].squeeze()[level].cpu().numpy().sum(axis=0))
# Out:
# <AxesSubplot:>

# %%
vis_word_embeds = F.normalize(image_embeds.squeeze(), dim=1)
sims = vis_word_embeds @ word_embeddings.T
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(20, 10))
literal_word = 'house'
search_word = word_embeddings[tokenizer.encode(literal_word)[-1]]
sim_map = (search_word @ vis_word_embeds.T).detach().cpu().numpy()[1:].reshape(16, 16)
threshold = np.percentile(sim_map.flatten(), 75)
sim_map[sim_map < threshold] = 0
sns.heatmap(sim_map, cbar=False, ax=ax2, zorder=5, linewidths=.5, alpha=.7, cmap='viridis')
ax2.imshow(view_image.permute(1,2,0),
          aspect = ax2.get_aspect(),
          extent = ax2.get_xlim() + ax2.get_ylim(),
          zorder = 1) #put the map under the heatmap
ax1.imshow(view_image.permute(1,2,0))
plt.title(f'Patches closest to {literal_word}')
# Out:
# Text(0.5, 1.0, 'Patches closest to house')

# %%
[tokenizer.decode(_) for _ in sims.topk(10, dim=-1).indices]
# Out:
# ['person only her hair make man like re scene s',
#  'accessories length throughout av alongside into champced sachal',
#  '##edlessces bernhard side avcedフ₂ steel',
#  'back champ horse lights gasmel at av s tap',
#  'gasostal aved back gold indianapolis champpel',
#  '##less trailer support dramahd श lights hip backs car',
#  'back gas at population payrollyslessos stmel',
#  '##less lane car hostility aspened doubtlitped diplomats',
#  'gold carless dramami at snow only velvet hanging',
#  'background covered built christmas at near are real lined together',
#  'aspen car lane diplomatsped onlyedᆸlessmed',
#  'aspen s only like av lanevi ladder gas salisbury',
#  'gas oilback street horse agingless frame face faces',
#  'lane gas oil horse aspen lights car truck man drivers',
#  '##edvi aspenom faceledeshd gas snow',
#  'aspen lane gas diplomatslesslitporgy dramas reserves',
#  'av gasfp backs driversless drivertalvieve',
#  '##ceslessed bikingpor steel payroll av mechanized ज',
#  'at background christmas are back is by on bright together',
#  '##ed gaslk 182 backspelmed lights only back',
#  'authentic sense background bright filming flashing members lights concrete probably',
#  '##nenlkhd 136 backs 1737pelmi lamvi',
#  'background built covered at christmas are near better lined play',
#  'display sense background female hood performer bright members current back',
#  "[CLS]...'viper,sumeentationidae ˡ wry",
#  'background star bright are at wire tourist together christmas were',
#  'lane aspen gas linden diplomatsless car does killinglid',
#  "[CLS]..., viper 'idaeentation - alyssa ˡ",
#  'lane killing aspen aprilvi kia gas car salisbury can',
#  'background are at wire tree tourist making progress christmas current',
#  'background christmas are at together bar future on real streets',
#  "[CLS]..., viper 'idaeentation ˡ - plague",
#  'carvi gaslitporopa whipless thighsed',
#  'ated frames st backis av cares obedience',
#  'gas caredlesss behind onlyoslit s',
#  'within changing author alongside participant grown colour en likeness detail',
#  'at gen back into av trim taken gastal champ',
#  'lightsosmedpel genmellitom salisbury videos',
#  '##lessnen draped carlkmivimelhd trailer',
#  "[CLS] wrysume'migrated prophecyentationidae [MASK]...",
#  'lane car aspen linden diplomatsᆸ spruce snow aggressioned',
#  'back side at car payroll gas s person alongside no',
#  'car lanehd backing gasommiedviped',
#  'originally alongside stands hung into joy actually sits punch trim',
#  'background are wire christmas at making bar star current future',
#  'lane gas aspen diplomatsvipor bracket abu april linden',
#  "[CLS]..., viperidae'- alyssa.entation",
#  '##om car paperhd gased lanevi street like',
#  "[CLS]..., 'entation insult wrysume -idae",
#  'behind supportless car only supported gaslaed aspen',
#  'at back gas by st way changing this part is',
#  'background christmas covered built at coffee lined are bar wheat',
#  'back car is horse faceed only ruined female at',
#  'retail background bright star taipei sense female loop cyclists out',
#  'car gas whiplitnen salisburyvi 205med 159',
#  'background are christmas at is together bar near back potential',
#  '##ed car snow lane aspenledped gasporpg',
#  '##edgy media gasled diplomats carged ma aspen',
#  'lane gas diplomats linden snow aspen rank cpg car',
#  "[CLS]..., viper 'idae plague insultentation alyssa",
#  'carpededvo snow12vi truck mahd',
#  'lane gaspor aspenvi supported diplomatsᆸ doesed',
#  '##ed card truck is gas supported vanvi like',
#  's gas made av at only drapeded pep carmel',
#  '##edosmed stefanolit bernhardes only s gas',
#  'at person back into by is gas st thiss',
#  'car reformerrb gasom 1651 only salisburyla behind',
#  '##sed car gas cute at reformerd operativesla',
#  'onlyvo support at draped can car like s velvet',
#  'av car shoulders only gas iscar backs whitetal',
#  'back a at see into s is make way life',
#  'car 205 draped broken stefanonengyᆸ salisbury diplomats',
#  '##in format s taken detail frames o stands hung snow',
#  '##ed person only s is likesped facees',
#  '##ed also s is way backs bracket off pump',
#  'background christmas at are covered real together is while of',
#  'car truck hanginges draped lane behindlessmi gas',
#  'background christmas together at are covered cane bright by in',
#  'christmas background together are at cane blurred bright byless',
#  'are bright performer box mirrors christmas crazy pedestrian somehow concrete',
#  '##ed bernhardgy third st onlyless peng s at',
#  'sliclersledgy st beat problemseddra',
#  'christmas background together are [CLS] at vietnam real future reproduction',
#  'gassed sdragylitt persony',
#  'only carless trucked van personsos bicycle',
#  'car support only s supported snow at vanedless',
#  'car only diplomats draped vanos personped aspen like',
#  '##edgedasled whipced shoulders backs backnen',
#  's irila frameslers 1692 351 bernhard alongside resurgence',
#  '##gy s head snowed heads insignificant onlyes forms',
#  'snow no way only goly s is customt',
#  'sed onlyes pengs car thirdgy skimmed',
#  'onlyed car ses minimedledless at',
#  'car whip onlylessedgy whitever shoulders side',
#  'side snow person lincoln right framesgyes proof not',
#  '##ed s only right lincolngy car person at along',
#  'side snow frames decentis ir reares yes back',
#  'against shoulders gas alongsideila saw gen champ beside back',
#  'streetleslers off 159 backedgy plate body 310',
#  'no case go way bracketly back has side snow',
#  '##lesledlic gasη problemslers s snow forerunner',
#  'no snowed case bracketis is decent go y',
#  'lace genisascedila trim frames y mirrored',
#  'side colourotes seen demo shape order rear lights',
#  'only person 1764ed reformer aspen thirdes 1732 artist',
#  '##esedgy ss head car snow forms is',
#  'snow custom go ised no st demo activation',
#  'order up seened off backos person trim scene',
#  'shoulders accessories saw population alongside trim wounding contrasted backed gen',
#  '##lesleddraila nmi alongdge mintealala',
#  'alonglesleddra s limbs secondila off twice',
#  '##licleddrales st shoulders sdge only hopeful',
#  '##less ir pep forerunner sideis car whipedgy',
#  'scene punch friend intoila shoulders champ gen hung outside',
#  'shoulders into ensemble within accessories champ against reila civilian',
#  '##ised demoer service off snowes at head',
#  'head personed ss twicees third forms day',
#  '##gyedes headpedy snow npr half s',
#  '##es ss personedped color truckgy face',
#  '##ledleses bernhard 161liclers y 274 s',
#  '##les alongesgedled म 1764 andersson bernhardη',
#  'headgyes sedged heads insignificant shiftal',
#  'headgyes sedy format edouard headsdra',
#  'gen av 182ged austriansila 1651eal punch 1692',
#  'shoulders accessoriesila assemblies stands scene 1658 costumesilo into',
#  'bernhardeslersgur snow head coloreal proofled',
#  'branches against bernhard backslers backed ⋅ilaeal austrians',
#  '[CLS] [MASK] inker cars makes meshcar high is',
#  'only proofgy twice head side sed offes',
#  'sideesised typeles forumsγ cavalierser',
#  'bracketeredleses framedصবﬂγ',
#  '##edesery 182tu customis bench alongside',
#  'custom headized y 1764sa bracketila 1651 182',
#  'yas alongyis proofxes framed prepared',
#  '##esles head ownedleds y 313 parade',
#  '##esles plate 182leded twice paradeeras',
#  '##esed side only colourisy head plates',
#  '##gy heades edouardy sgededγeal',
#  '##esed head persongederilalesas off',
#  '##es head twice sidelesisas slers parade',
#  'alongedes headtu headslesercha walks',
#  '##essuls parade headis heads seal only',
#  '##es proofisiladra heads head 1778 yised',
#  'proofgyis snowfe irisedglyesila',
#  'twice s proofes kato only alongdra 161 bernhard',
#  'straightgur beat face itsgle college transcript back division',
#  'divisiongle beat heads college back im sight off half',
#  'division headslicgle college transcript testgur prime beat',
#  'college division bust headsgle mer back beat transfer farm',
#  'twice beat mer heads division form sight collegegle back',
#  'division college twice bustgle farm heads spur batter access',
#  'division collegeix bust off freed spur twice access ru',
#  'division collegegur pensgle batterix accesslic bust',
#  '##ila spur trim 182 rucek prime 41 lightis',
#  'transformedles meadow scene s mer within reductions walksila',
#  '##is headasصes forerunnerles twisted heads custom',
#  'head farmgley custom inchvisevefp competitor',
#  '##essul colouris custom forerunnerɴgurised м',
#  'head customeser colour snowised alongside color feather',
#  '##es forums faceles side twisted forerunner bernhard travelsis',
#  'colour s 1692 top 210 plate color 122 51 1580',
#  'trim gas everything person scene em as length flashed skies',
#  '##gle gauge nprgur reelinggles4yx classrooms',
#  'prime formpostiza gauge4 daylight forums ivory ingrid',
#  'collegegle gauge division test off farm accessy bust',
#  'college formy primeed forms farm dimensions gauge division',
#  '##ixyson prime ram college sports varietytour form protege',
#  'college divisiongle heads cipherix testgent transformed form',
#  'collegegle division bust farm heads transformed testgent transfer',
#  'collegegle transformed farm spur bust fast division brand quarter',
#  '##y funding subjects sitila slipped mammoth trainer sits wrenched',
#  'collegegle division competitor heads test ru spur transformed bust',
#  'head division hostel f platform selector quarter scale birthdayy',
#  'f transformed twice anglia cipher 1b sign playhouse college transformations',
#  'division college headsix scene bust mer transformed farm gs',
#  'collegegle heads anglia division head competitor bustixlic',
#  'division twice transformed beatchangle collegegel trophy heads',
#  'beat test mode back head off sight spot heartbeat under',
#  'mode beat goat soundgle reindeer sight pig unicorn musician',
#  'with off trimedglegedes person rare4',
#  '##gle via sports with off personed4 media several',
#  '##gle off its face only leg farmgy gauge keys',
#  '##gle collegey as head forms quarter base straight test',
#  'prime college gauge formwn colour pensglepost gs',
#  'college carlaiza selectorlessliga provisiontour trent off',
#  'collegegyes quarterila got collar milk headged',
#  'situated王 enlargedila edouarded muriel protector partitiondown',
#  'mccartney prime selector sabotage थ clandestine super cipher forums fellowships',
#  'collegegle blackberry heads transfer transformed test selector hollowayila',
#  'ribgle mccartney snatched badge steal ß reporter bust prime',
#  "[CLS] [MASK] rogue contamination legal kepler migrated'afibin",
#  'college beat bust headsgle joy blackberry test sightcolor',
#  '##gle twice heads bust lifted custom transformed collegeix transfer',
#  'back beat off mess mode undergle heartbeat car head',
#  '##gle imtal clearumi off lacey reindeer brand blackberry',
#  'reindeerª acoustic gauge offtallessiza peptide hung',
#  'with off4x trim5gle 050 sealed person',
#  'with48 15 beautiful coffee off5 sealed media',
#  'person off with several business ses sealed rare4',
#  'persongle syes off right its media face',
#  'leaves4gle leges form college looks classeve',
#  'form life hostses5ᴬ iona deposits ks bronze',
#  '##王 repression wonder forums protectorila constituted lowered revokedᄉ',
#  '##ص college forums selector offes beat fringeeve facebook',
#  '##es devin college hollowaygle գ alvaroeveless dice',
#  'college provision alvaroeveiza offwnesless devin',
#  'collegegle selectoreve provision mutefp cipher 1972 off',
#  'background reproduction bright squirrel vietnam pedestal bust christmas tourist daylight',
#  '##gle beat transfer headsgled administrative patron lifted bronze heartbeat',
#  'beat stefano mess hung deccaiza act onlyopa lace',
#  'cargle off pig hung mess helicoptertalopa college',
#  '##gle form college sound cipher erin only reindeer mode forms',
#  'soundniesless rushes unicorn wood synth twice goat panic',
#  '##fpless hung plus rushesizalicis offte',
#  'background christmas are at by real together of built and',
#  'off58 with4 4 col five9 5',
#  'off person with4 frames media9 sealeded 15',
#  'snowed abandoned other person framesgedes several beautiful',
#  'frames forms networks forums plus forumes clara ru custom',
#  '##gle rampedesgyged media off face farm',
#  'offglees fringegyeve4 college legus',
#  'form college forms class leaveschan crowns person obedience4',
#  'form descent flashinggy aggravated scaleless straight fringejected',
#  'form plusless only scale mail dignity claraص prime',
#  '##gle selector snatched holloway beat agnes fee benefactor andre sabotage',
#  'portrait chan hungos em against shoulders accessories name into',
#  'beat offª [unused844] peptide hung mode plea facebook feb',
#  '##umi off rackgle beat college back coverless under',
#  '##y type rushless order form heartbeat design runs heads',
#  'wood sound only country rushes head character joykaib',
#  'shoulders off trim side top person clock av equestrian with',
#  'with col8 off back4 15 sealed right9',
#  'shoulders em into accessories length taken back re pit scene',
#  '##es meadow service plusor garmented pasture medias',
#  '##es meadow those custom frames yellow beautiful bronzeor pond',
#  'off with person 15 media sealed around several five at',
#  'with off person media its4 right several from sealed',
#  '##gle ramp payrollfc edouard walks wonder braceopa form',
#  '##gle off size rushgy get gets meadow beats only',
#  '##gy farm offgle form edouardged programmes only beat',
#  '##glegyfp beat friend alongside beats wire own form',
#  '##gley alongsidees transcriptフos 1764washed beat',
#  '##gleless still under hung off transcriptis time film',
#  'off beat transcriptiza collegelic selector backed importsgle',
#  '##iza hunggley phone henrik heartbeatfp beat 1685',
#  'hung off hound reindeer erection peptide alone featlessmobile',
#  'hung soundless v wood guitaris joy aloneka',
#  '##ter sound hung woodistal guitar parish serena electric',
#  'off hungbasgle film rushesopa back sight imp',
#  'person snow baby park light animal back sealed off hand',
#  'frames location person snow floor lincoln animal gas water park',
#  'back scene av shoulders co pillows made lo sans length',
#  'with snow off its back 15 right person side park',
#  'its with snow person gas ir off back handes',
#  'hand all its person 15 gas snow back half off',
#  '##ed off gas icegy top lovees s with',
#  'shoulders accessoriesila back npr gas iron aroundoton clock']

# %%
sim_map.min()
# Out:
# -0.04822644

# %%
sim_map.flatten().shape
# Out:
# (256,)
