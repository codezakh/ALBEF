# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
albef = [
    {'txt_r1': 55.4, 'txt_r5': 81.5, 'txt_r10': 88.5, 'txt_r_mean': 75.13333333333334, 'img_r1': 45.46, 'img_r5': 74.3, 'img_r10': 83.94, 'img_r_mean': 67.89999999999999, 'r_mean': 71.51666666666667},
    {'txt_r1': 59.5, 'txt_r5': 85.6, 'txt_r10': 91.5, 'txt_r_mean': 78.86666666666666, 'img_r1': 50.52, 'img_r5': 78.4, 'img_r10': 86.32, 'img_r_mean': 71.74666666666667, 'r_mean': 75.30666666666667},
    {'txt_r1': 58.0, 'txt_r5': 85.8, 'txt_r10': 92.1, 'txt_r_mean': 78.63333333333334, 'img_r1': 50.76, 'img_r5': 78.8, 'img_r10': 86.46, 'img_r_mean': 72.00666666666666, 'r_mean': 75.32},
    {'txt_r1': 65.3, 'txt_r5': 89.3, 'txt_r10': 94.5, 'txt_r_mean': 83.03333333333333, 'img_r1': 54.12, 'img_r5': 80.96, 'img_r10': 88.64, 'img_r_mean': 74.57333333333332, 'r_mean': 78.80333333333333},
    {'txt_r1': 61.3, 'txt_r5': 87.6, 'txt_r10': 93.6, 'txt_r_mean': 80.83333333333333, 'img_r1': 51.76, 'img_r5': 80.76, 'img_r10': 87.54, 'img_r_mean': 73.35333333333334, 'r_mean': 77.09333333333333},
    {'txt_r1': 70.1, 'txt_r5': 91.1, 'txt_r10': 95.7, 'txt_r_mean': 85.63333333333333, 'img_r1': 54.08, 'img_r5': 81.98, 'img_r10': 89.2, 'img_r_mean': 75.08666666666666, 'r_mean': 80.35999999999999},
    {'txt_r1': 69.5, 'txt_r5': 90.1, 'txt_r10': 94.7, 'txt_r_mean': 84.76666666666667, 'img_r1': 54.68, 'img_r5': 82.2, 'img_r10': 89.14, 'img_r_mean': 75.33999999999999, 'r_mean': 80.05333333333333},
    {'txt_r1': 70.7, 'txt_r5': 91.6, 'txt_r10': 96.0, 'txt_r_mean': 86.10000000000001, 'img_r1': 55.14, 'img_r5': 81.98, 'img_r10': 88.68, 'img_r_mean': 75.26666666666667, 'r_mean': 80.68333333333334},
    {'txt_r1': 70.4, 'txt_r5': 92.4, 'txt_r10': 96.2, 'txt_r_mean': 86.33333333333333, 'img_r1': 53.98, 'img_r5': 81.28, 'img_r10': 88.42, 'img_r_mean': 74.56, 'r_mean': 80.44666666666666},
    {'txt_r1': 69.0, 'txt_r5': 90.3, 'txt_r10': 95.6, 'txt_r_mean': 84.96666666666667, 'img_r1': 54.7, 'img_r5': 80.94, 'img_r10': 87.96, 'img_r_mean': 74.53333333333332, 'r_mean': 79.75}
]

# %%
simla = [
    {'txt_r1': 48.4, 'txt_r5': 79.4, 'txt_r10': 89.0, 'txt_r_mean': 72.26666666666667, 'img_r1': 47.5, 'img_r5': 77.28, 'img_r10': 85.86, 'img_r_mean': 70.21333333333332, 'r_mean': 71.24},
    {'txt_r1': 59.8, 'txt_r5': 85.3, 'txt_r10': 92.0, 'txt_r_mean': 79.03333333333333, 'img_r1': 52.2, 'img_r5': 79.48, 'img_r10': 87.8, 'img_r_mean': 73.16000000000001, 'r_mean': 76.09666666666666},
    {'txt_r1': 67.5, 'txt_r5': 90.1, 'txt_r10': 95.0, 'txt_r_mean': 84.2, 'img_r1': 51.96, 'img_r5': 80.6, 'img_r10': 87.88, 'img_r_mean': 73.48, 'r_mean': 78.84},
    {'txt_r1': 69.4, 'txt_r5': 90.3, 'txt_r10': 95.0, 'txt_r_mean': 84.89999999999999, 'img_r1': 54.28, 'img_r5': 81.84, 'img_r10': 88.84, 'img_r_mean': 74.98666666666666, 'r_mean': 79.94333333333333},
    {'txt_r1': 72.1, 'txt_r5': 92.9, 'txt_r10': 96.3, 'txt_r_mean': 87.10000000000001, 'img_r1': 54.98, 'img_r5': 82.68, 'img_r10': 89.48, 'img_r_mean': 75.71333333333332, 'r_mean': 81.40666666666667},
    {'txt_r1': 71.3, 'txt_r5': 92.1, 'txt_r10': 96.2, 'txt_r_mean': 86.53333333333332, 'img_r1': 56.16, 'img_r5': 83.08, 'img_r10': 89.92, 'img_r_mean': 76.38666666666667, 'r_mean': 81.46},
    {'txt_r1': 71.1, 'txt_r5': 93.2, 'txt_r10': 96.3, 'txt_r_mean': 86.86666666666667, 'img_r1': 57.42, 'img_r5': 83.5, 'img_r10': 90.38, 'img_r_mean': 77.10000000000001, 'r_mean': 81.98333333333335},
    {'txt_r1': 71.5, 'txt_r5': 93.0, 'txt_r10': 96.8, 'txt_r_mean': 87.10000000000001, 'img_r1': 56.82, 'img_r5': 83.54, 'img_r10': 90.42, 'img_r_mean': 76.92666666666668, 'r_mean': 82.01333333333335},
    {'txt_r1': 72.8, 'txt_r5': 91.4, 'txt_r10': 96.5, 'txt_r_mean': 86.89999999999999, 'img_r1': 54.7, 'img_r5': 81.42, 'img_r10': 88.58, 'img_r_mean': 74.89999999999999, 'r_mean': 80.89999999999999},
    {'txt_r1': 72.0, 'txt_r5': 92.2, 'txt_r10': 96.5, 'txt_r_mean': 86.89999999999999, 'img_r1': 55.2, 'img_r5': 82.2, 'img_r10': 89.54, 'img_r_mean': 75.64666666666666, 'r_mean': 81.27333333333333}
]

# %%
def set_size(width, fraction=1, height_divisor=2):
    """Set figure dimensions to avoid scaling in LaTeX.
    
    Insert \showthe\textwidth in the document, and grep the logs
    for something like:
    
    > 345.0pt.
    l.5 \showthe\textwidth

    Parameters
    ----------
    width: float
            Document textwidth or columnwidth in pts
    fraction: float, optional
            Fraction of the width which you wish the figure to occupy

    Returns
    -------
    fig_dim: tuple
            Dimensions of figure in inches
    """
    # Width of figure (in pts)
    fig_width_pt = width * fraction

    # Convert from pt to inches
    inches_per_pt = 1 / 72.27

    # Golden ratio to set aesthetic figure height
    # https://disq.us/p/2940ij3
    golden_ratio = (5**.5 - 1) / 2

    # Figure width in inches
    fig_width_in = fig_width_pt * inches_per_pt
    # Figure height in inches
    fig_height_in = fig_width_in * golden_ratio

    fig_dim = (fig_width_in, fig_height_in / height_divisor)

    return fig_dim

# %%
albef = pd.DataFrame(albef)

# %%
simla = pd.DataFrame(simla)

# %%
plt.plot(np.arange(10), albef.txt_r1.values, c='grey')
plt.scatter(9, albef.txt_r1.values[-1], marker='o', c='black')
plt.plot(np.arange(10), simla.txt_r1.values, c='red')
plt.scatter(9, simla.txt_r1.values[-1], marker='x', c='red')

# %%
plt.plot(np.arange(10), albef.txt_r_mean.values, c='grey')
plt.scatter(9, albef.txt_r_mean.values[-1], marker='o', c='black')
plt.plot(np.arange(10), simla.txt_r_mean.values, c='red')
plt.scatter(9, simla.txt_r_mean.values[-1], marker='x', c='red')

# %%
plt.plot(np.arange(10), albef.r_mean.values, c='grey')
plt.scatter(9, albef.r_mean.values[-1], marker='o', c='black')
plt.plot(np.arange(10), simla.r_mean.values, c='red')
plt.scatter(9, simla.r_mean.values[-1], marker='x', c='red')

# %%
text_width = 496.85625/2
set_size(text_width, height_divisor=2)
# Out:
# (3.4375, 1.062245918163882)

# %%
fig, (ax1, ax2, ax3, ax4) = plt.subplots(nrows=1, ncols=4, figsize=(6.875/2, 2.124491836327764/2))
metrics = ['txt_r1', 'img_r1', 'txt_r_mean', 'img_r_mean']
axes = [ax1, ax2, ax3, ax4]
titles = ['TR@1', 'IR@1', 'TR Mean', 'IR Mean']
xticks = [0, 2, 4, 6, 8]
xticklabels = [(_ + 1) * 32 for _ in xticks]
for metric, ax, title in zip(metrics, axes, titles):
    ax.plot(np.arange(10), albef[metric].values, c='grey', label='ALBEF')
    ax.scatter(9, albef[metric].values[-1], marker='o', c='black')
    ax.plot(np.arange(10), simla[metric].values, c='red', label='SIMLA')
    ax.scatter(9, simla[metric].values[-1], marker='x', c='red')
    ax.set_title(title)
    ax.set_xticks(xticks, labels=xticklabels, rotation=45)
fig.supylabel('Flickr30K 0-shot\n(1k test set)')
fig.supxlabel('GPU Hours')
plt.tight_layout()
ax.legend(ncol=2, loc='lower center', bbox_to_anchor=(0, -1.2))
#plt.savefig('data-efficiency.pdf')
# Out:
# /home/mai/zkhan/miniconda3/envs/ssl/lib/python3.7/site-packages/ipykernel_launcher.py:16: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   app.launch_new_instance()

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2, figsize=(3.4375, 2), sharex=True)
metrics = ['txt_r1', 'img_r1', 'txt_r_mean', 'img_r_mean']
axes = [ax1, ax2, ax3, ax4]
titles = ['TR@1', 'IR@1', 'TR Mean', 'IR Mean']
xticks = [0, 2, 4, 6, 8]
xticklabels = [(_ + 1) * 32 for _ in xticks]
for metric, ax, title in list(zip(metrics, axes, titles)):
    ax.plot(np.arange(10), albef[metric].ewm(2).mean().values, c='grey', label='ALBEF')
    ax.scatter(np.arange(10), albef[metric].values, c='grey', label='ALBEF', marker='x', alpha=0.5)
    ax.scatter(9, albef[metric].values[-1], marker='o', c='grey')
    ax.plot(np.arange(10), simla[metric].ewm(2).mean().values, c='red', label='SIMLA')
    ax.scatter(np.arange(10), simla[metric].values, c='red', label='SIMLA', marker='x', alpha=0.5)
    ax.scatter(9, simla[metric].values[-1], marker='o', c='red')
    #ax.set_title(title)
    ax.set_xticks(xticks, labels=xticklabels, rotation=45)
ax2.yaxis.tick_right()
ax4.yaxis.tick_right()
#fig.supylabel('Flickr 0-shot Acc', x=0.1)
fig.supxlabel('GPU Hours', y=0.15)
plt.tight_layout()
fig.subplots_adjust(wspace=0, hspace=0,)
#ax.legend(ncol=2, loc='lower center', bbox_to_anchor=(0, -1.2))
plt.savefig('data-efficiency-rebuttal.pdf')

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(3.4375, 1.0), sharex=True)
metrics = ['txt_r1', 'img_r1', 'txt_r_mean', 'img_r_mean']
axes = [ax1, ax2] * 2
titles = ['TR@1', 'IR@1', 'TR Mean', 'IR Mean']
xticks = [0, 2, 4, 6, 8]
xticklabels = [(_ + 1) * 32 for _ in xticks]
s=10
linewidth=1
xticklabels[1:-1] = ['', 'GPU Hours', '']
for metric, ax, title in list(zip(metrics, axes, titles))[-2:]:
    ax.plot(np.arange(10), albef[metric].ewm(1).mean().values, c='grey', label='ALBEF', linewidth=linewidth)
    ax.scatter(np.arange(10), albef[metric].values, c='grey', marker='x', alpha=0.5, s=s, linewidth=linewidth/2)
    ax.scatter(9, albef[metric].values[-1], marker='o', c='grey', s=s)
    ax.plot(np.arange(10), simla[metric].ewm(1).mean().values, c='red', label='SIMLA', linewidth=linewidth)
    ax.scatter(np.arange(10), simla[metric].values, c='red', marker='x', alpha=0.5, s=s, linewidth=linewidth/2)
    ax.scatter(9, simla[metric].values[-1], marker='o', c='red', s=s)
    #ax.set_title(title)
    ax.set_xticks(xticks, labels=xticklabels, rotation=0)
ax1.yaxis.tick_right()
#ax4.yaxis.tick_right()
#fig.supylabel('Flickr 0-shot Acc', x=0.1)
#fig.supxlabel('GPU Hours', y=0.15)
plt.tight_layout()
fig.subplots_adjust(wspace=0.5, hspace=0,)
plt.rcParams.update({'font.size': 7})
plt.rcParams.update({'font.family': 'serif'})
#ax.legend(ncol=1, loc='lower center', bbox_to_anchor=(-0.3, .2))
plt.savefig('data-efficiency-rebuttal.pdf')

# %%
fig, (ax1, ax2) = plt.subplots(nrows=2, ncols=1, figsize=(3.4375, 1.3), sharey=True)
metrics = ['txt_r1', 'img_r1', 'txt_r_mean', 'img_r_mean']
axes = [ax1, ax2] * 2
titles = ['TR@1', 'IR@1', 'TR Mean', 'IR Mean']
xticks = [0, 2, 4, 6, 8]
xticklabels = [(_ + 1) * 32 for _ in xticks]
for metric, ax, title in list(zip(metrics, axes, titles))[-2:]:
    ax.plot(np.arange(10), albef[metric].ewm(1).mean().values, c='grey', label='ALBEF')
    ax.scatter(np.arange(10), albef[metric].values, c='grey', label='ALBEF', marker='x', alpha=0.5)
    ax.scatter(9, albef[metric].values[-1], marker='o', c='grey')
    ax.plot(np.arange(10), simla[metric].ewm(1).mean().values, c='red', label='SIMLA')
    ax.scatter(np.arange(10), simla[metric].values, c='red', label='SIMLA', marker='x', alpha=0.5)
    ax.scatter(9, simla[metric].values[-1], marker='o', c='red')
    #ax.set_title(title)
    ax.set_xticks(xticks, labels=xticklabels, rotation=45)
ax2.yaxis.tick_right()
ax4.yaxis.tick_right()
#fig.supylabel('Flickr 0-shot Acc', x=0.1)
#fig.supxlabel('GPU Hours', y=0.15)
plt.tight_layout()
fig.subplots_adjust(wspace=0, hspace=0,)
#ax.legend(ncol=2, loc='lower center', bbox_to_anchor=(0, -1.2))
plt.savefig('data-efficiency-rebuttal.pdf')
